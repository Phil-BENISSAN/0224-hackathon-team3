# %%
import pandas as pd

df = pd.read_csv("df_personnages.csv")

# %%
df1 = pd.read_csv("df_personnes_celebres.csv")
df
# Out:
#                                                   Nom  \
# 0                        Marie Curie, la scientifique
# 1                             Coco Chanel, l’élégante
# 2                 Joséphine Baker, la star de couleur
# 3                       Marlène Dietrich, l’ange bleu
# 4                              Anne Frank, la victime
# 5             Simone de Beauvoir, la femme de lettres
# 6                          Mère Teresa, la religieuse
# 7                   Françoise Sagan, le petit monstre
# 8                    Brigitte Bardot, la femme fatale
# 9                       Marilyn Monroe, la sex-symbol
# 10                                Edith Piaf, la môme
# 11                       Simone Veil, la femme de loi
# 12                Sheila, la chanteuse internationale
# 13              Nana Mouskouri, la voix de la liberté
# 14                         Jeannie Longo, la sportive
# 15                      Lady Di, la princesse de cœur
# ...

# %%
my_list = [
  {
    "title": "dfhgfshsfjskjsyxk",
    "idea": "string"
  },
  {
    "title": "titi",
    "idea": "string"
  },
  {
    "title": "dudu",
    "idea": "string"
  }
]

# %%
df = pd.DataFrame(my_list)
df
# Out:
#                title    idea
# 0  dfhgfshsfjskjsyxk  string
# 1               titi  string
# 2               dudu  string

# %%
df.to_csv("ideas.csv", index=False)

# %%
import pandas as pd

# %%
df = pd.read_csv("ideas_box.csv")
display(df)
store_ideas = df.to_dict('records')

item = {
  "title": "ffffff",
  "idea": "string"
}

store_ideas.append(item)    
        
df = pd.DataFrame(store_ideas)
display(df)
df.to_csv("ideas_box.csv", index=False)
# Out:
#                                  title  \
# 0                     Horaire flexible
# 1                          Télétravail
# 2                       Reconnaissance
# 3                   Espaces de détente
# 4                   Événements sociaux
# 5               Programmes de mentorat
# 6      Meilleure communication interne
# 7      Soutien à la formation continue
# 8              Initiatives écologiques
# 9              Aménagement des bureaux
# 10      Cafétéria ou cantine améliorée
# 11                           Transport
# 12                 Partenariats locaux
# 13  Feedback sur les outils de travail
# 14                   Bénéfices sociaux
#
#                                                  idea
# 0   Proposer des horaires de travail plus souples ...
# 1   Augmenter les possibilités de travailler de ch...
# 2   Mettre en place un système pour reconnaître le...
# 3   Créer ou améliorer des zones de pause pour se ...
# 4   Organiser des événements pour renforcer l'espr...
# ...

# %%
df = pd.read_csv("ideas_box.csv")
store_ideas = df.to_dict('records')
store_ideas
# Out:
# [{'title': 'Horaire flexible',
#   'idea': 'Proposer des horaires de travail plus souples pour mieux gérer boulot et vie perso.'},
#  {'title': 'Télétravail',
#   'idea': 'Augmenter les possibilités de travailler de chez soi.'},
#  {'title': 'Reconnaissance : Mettre en place un système pour reconnaître les efforts et réussites des collègues.',
#   'idea': nan},
#  {'title': 'Espaces de détente : Créer ou améliorer des zones de pause pour se relaxer un peu.',
#   'idea': nan},
#  {'title': "Événements sociaux : Organiser des événements pour renforcer l'esprit d'équipe.",
#   'idea': nan},
#  {'title': 'Programmes de mentorat : Lancer des programmes de mentorat pour aider à progresser dans le boulot.',
#   'idea': nan},
#  {'title': 'Meilleure communication interne : Utiliser de nouveaux outils ou méthodes pour mieux communiquer en interne.',
#   'idea': nan},
#  {'title': 'Soutien à la formation continue : Offrir des aides pour des formations ou des cours en ligne.',
# ...
